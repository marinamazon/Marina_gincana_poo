# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class time :
    def __init__(self, nome, pontos, classificação):
       
        self.nome = nome
        self.pontos = pontos
        self.classificação = classificação

    def dados(self):
        print(f"Nome: {self.nome}")
        print(f"Pontos: {self.pontos}")
        print(f"Classificação: {self.classificação}")

Time_Azul = time("Time_Azul", 90, "1' Lugar")
Time_Vermelho = time("Time_Vermelho", 75, "3' Lugar")

Time_Azul.dados()
print("-------------------")
Time_Vermelho.dados()
# Out:
# Nome: Time_Azul
# pontos: 90
# classificação: 1' Lugar
# -------------------
# Nome: Time_Vermelho
# pontos: 75
# classificação: 3' Lugar

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
# Classe principal
class Gincana:
    def __init__(self, nome, data):
        self.nome = nome
        self.data = data
        self.equipes = []

    def adicionar_equipe(self, equipe):
        self.equipes.append(equipe)
        print(f"Equipe '{equipe}' adicionada à gincana '{self.nome}'.")

    def listar_equipes(self):
        print(f"Equipes da gincana '{self.nome}':")
        for equipe in self.equipes:
            print(f"- {equipe}")

# Subclasse herdando de Gincana
class GincanaTematica(Gincana):
    def __init__(self, nome, data, tema):
        super().__init__(nome, data)  # Utilizando super() para herdar
        self.tema = tema  # Novo atributo exclusivo

    def mostrar_tema(self):  # Novo método exclusivo da subclasse
        print(f"O tema da gincana '{self.nome}' é: {self.tema}")

# Teste do código
g1 = Gincana("Gincana de Matemática", "2025-06-20")
g1.adicionar_equipe("Alfa")
g1.adicionar_equipe("Beta")
g1.listar_equipes()

print("\n---\n")

gt = GincanaTematica("Gincana Cultural", "2025-07-15", "Folclore Brasileiro")
gt.adicionar_equipe("Tupã")
gt.adicionar_equipe("Curupira")
gt.listar_equipes()
gt.mostrar_tema()
# Out:
# Equipe 'Alfa' adicionada à gincana 'Gincana de Matemática'.
# Equipe 'Beta' adicionada à gincana 'Gincana de Matemática'.
# Equipes da gincana 'Gincana de Matemática':
# - Alfa
# - Beta
#
# ---
#
# Equipe 'Tupã' adicionada à gincana 'Gincana Cultural'.
# Equipe 'Curupira' adicionada à gincana 'Gincana Cultural'.
# Equipes da gincana 'Gincana Cultural':
# - Tupã
# - Curupira
# O tema da gincana 'Gincana Cultural' é: Folclore Brasileiro

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Gincana:
    def __init__(self, nome, data):
        self.__nome = nome  # Atributo privado
        self.data = data
        self.equipes = {}

    # Métodos get e set para o nome (encapsulamento)
    def get_nome(self):
        return self.__nome

    def set_nome(self, novo_nome):
        if len(novo_nome.strip()) >= 3:
            self.__nome = novo_nome
        else:
            print("Nome inválido. Deve ter pelo menos 3 letras.")

    # Adicionar equipe com pontuação inicial 0
    def adicionar_equipe(self, equipe):
        if equipe not in self.equipes:
            self.equipes[equipe] = 0
            print(f"Equipe '{equipe}' adicionada.")
        else:
            print("Equipe já cadastrada.")

    # Atribuir pontos a uma equipe (lógica interna)
    def registrar_pontos(self, equipe, pontos):
        if equipe in self.equipes:
            self.equipes[equipe] += pontos
            print(f"{pontos} ponto(s) adicionados à equipe '{equipe}'.")
        else:
            print("Equipe não encontrada.")

    # Mostrar pontuação
    def mostrar_pontuacoes(self):
        print(f"Pontuações da gincana '{self.__nome}':")
        for equipe, pontos in self.equipes.items():
            print(f"- {equipe}: {pontos} ponto(s)")

# Teste
g = Gincana("Gincana de Ciências", "2025-09-10")
print("Nome original:", g.get_nome())

g.set_nome("Ciência Show")  # Setter com validação
print("Novo nome:", g.get_nome())

g.adicionar_equipe("Equipe Azul")
g.adicionar_equipe("Equipe Verde")

g.registrar_pontos("Equipe Azul", 10)
g.registrar_pontos("Equipe Verde", 15)

g.mostrar_pontuacoes()
# Out:
# Nome original: Gincana de Ciências
# Novo nome: Ciência Show
# Equipe 'Equipe Azul' adicionada.
# Equipe 'Equipe Verde' adicionada.
# 10 ponto(s) adicionados à equipe 'Equipe Azul'.
# 15 ponto(s) adicionados à equipe 'Equipe Verde'.
# Pontuações da gincana 'Ciência Show':
# - Equipe Azul: 10 ponto(s)
# - Equipe Verde: 15 ponto(s)

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3

# Classe base
class Gincana:
    def __init__(self, nome, data):
        self.nome = nome
        self.data = data

    def descricao(self):
        return f"Gincana: {self.nome} - Data: {self.data}"

    def salvar_no_banco(self):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS gincanas (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT,
                data TEXT,
                tipo TEXT
            )
        """)
        cursor.execute("INSERT INTO gincanas (nome, data, tipo) VALUES (?, ?, ?)",
                       (self.nome, self.data, "Comum"))
        conn.commit()
        conn.close()

    @staticmethod
    def listar_gincanas():
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("SELECT id, nome, data, tipo FROM gincanas")
        registros = cursor.fetchall()
        conn.close()

        print("📋 Gincanas cadastradas:")
        for r in registros:
            print(f"ID: {r[0]} | Nome: {r[1]} | Data: {r[2]} | Tipo: {r[3]}")

    @staticmethod
    def excluir_gincana(id_gincana):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM gincanas WHERE id = ?", (id_gincana,))
        conn.commit()
        conn.close()
        print(f"Gincana com ID {id_gincana} excluída.")

# Subclasse com polimorfismo
class GincanaTematica(Gincana):
    def __init__(self, nome, data, tema):
        super().__init__(nome, data)
        self.tema = tema

    def descricao(self):  # POLIMORFISMO (método sobrescrito)
        return f"Gincana Temática: {self.nome} - Data: {self.data} - Tema: {self.tema}"

    def salvar_no_banco(self):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS gincanas (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT,
                data TEXT,
                tipo TEXT
            )
        """)
        cursor.execute("INSERT INTO gincanas (nome, data, tipo) VALUES (?, ?, ?)",
                       (self.nome, self.data, f"Temática: {self.tema}"))
        conn.commit()
        conn.close()

# Testes
g1 = Gincana("Gincana Esportiva", "2025-09-01")
print(g1.descricao())
g1.salvar_no_banco()

g2 = GincanaTematica("Gincana Cultural", "2025-09-20", "Cultura Nordestina")
print(g2.descricao())  # Polimorfismo
g2.salvar_no_banco()

print("\n--- CONSULTA ---")
Gincana.listar_gincanas()

print("\n--- EXCLUSÃO ---")
Gincana.excluir_gincana(1)  # Exclui gincana com ID 1 (ajuste conforme seus dados)
Gincana.listar_gincanas()
# Out:
# Gincana: Gincana Esportiva - Data: 2025-09-01
# Gincana Temática: Gincana Cultural - Data: 2025-09-20 - Tema: Cultura Nordestina
#
# --- CONSULTA ---
# 📋 Gincanas cadastradas:
# ID: 1 | Nome: Gincana Esportiva | Data: 2025-09-01 | Tipo: Comum
# ID: 2 | Nome: Gincana Cultural | Data: 2025-09-20 | Tipo: Temática: Cultura Nordestina
#
# --- EXCLUSÃO ---
# Gincana com ID 1 excluída.
# 📋 Gincanas cadastradas:
# ID: 2 | Nome: Gincana Cultural | Data: 2025-09-20 | Tipo: Temática: Cultura Nordestina

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5]
import sqlite3

# === CLASSE PRINCIPAL: GINCANA ===
class Gincana:
    def __init__(self, nome, data):
        self.__nome = nome  # Atributo privado (ENCAPSULAMENTO)
        self.data = data
        self.equipes = {}

    # Get e Set do nome (Encapsulamento)
    def get_nome(self):
        return self.__nome

    def set_nome(self, novo_nome):
        if len(novo_nome.strip()) >= 3:
            self.__nome = novo_nome
        else:
            print("Nome inválido.")

    # Adiciona uma equipe à gincana
    def adicionar_equipe(self, equipe):
        if equipe not in self.equipes:
            self.equipes[equipe] = 0
            print(f"✅ Equipe '{equipe}' adicionada.")
        else:
            print("⚠️ Equipe já existe.")

    # Atribui pontos a uma equipe (ABSTRAÇÃO com lógica)
    def registrar_pontos(self, equipe, pontos):
        if equipe in self.equipes:
            self.equipes[equipe] += pontos
        else:
            print("❌ Equipe não encontrada.")

    # Mostra as pontuações
    def mostrar_pontuacoes(self):
        print(f"📋 Pontuação da gincana '{self.__nome}':")
        for equipe, pontos in self.equipes.items():
            print(f"- {equipe}: {pontos} ponto(s)")

    # Descrição da gincana (para polimorfismo)
    def descricao(self):
        return f"Gincana comum: {self.__nome} | Data: {self.data}"

    # SALVAR NO BANCO
    def salvar_no_banco(self):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS gincanas (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT,
                data TEXT,
                tipo TEXT
            )
        """)
        cursor.execute("INSERT INTO gincanas (nome, data, tipo) VALUES (?, ?, ?)",
                       (self.__nome, self.data, "Comum"))
        conn.commit()
        conn.close()

    # LISTAR DO BANCO
    @staticmethod
    def listar_gincanas():
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("SELECT id, nome, data, tipo FROM gincanas")
        registros = cursor.fetchall()
        conn.close()

        print("\n📚 Gincanas cadastradas:")
        for r in registros:
            print(f"ID: {r[0]} | Nome: {r[1]} | Data: {r[2]} | Tipo: {r[3]}")

    # EXCLUIR DO BANCO
    @staticmethod
    def excluir_gincana(id_gincana):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("DELETE FROM gincanas WHERE id = ?", (id_gincana,))
        conn.commit()
        conn.close()
        print(f"🗑️ Gincana com ID {id_gincana} foi excluída.")

# === SUBCLASSE: GINCANA TEMÁTICA ===
class GincanaTematica(Gincana):
    def __init__(self, nome, data, tema):
        super().__init__(nome, data)  # super() = herda do construtor da classe pai
        self.tema = tema

    # POLIMORFISMO: sobrescrevendo o método descricao()
    def descricao(self):
        return f"Gincana Temática: {self.get_nome()} | Data: {self.data} | Tema: {self.tema}"

    # Sobrescrevendo salvar para incluir tema
    def salvar_no_banco(self):
        conn = sqlite3.connect("gincanas.db")
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS gincanas (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT,
                data TEXT,
                tipo TEXT
            )
        """)
        cursor.execute("INSERT INTO gincanas (nome, data, tipo) VALUES (?, ?, ?)",
                       (self.get_nome(), self.data, f"Temática: {self.tema}"))
        conn.commit()
        conn.close()

# === TESTES DO SISTEMA FINAL ===

print("=== TESTE 1: Gincana comum ===")
g1 = Gincana("Gincana Esportiva", "2025-10-01")
g1.adicionar_equipe("Leões")
g1.adicionar_equipe("Tigres")
g1.registrar_pontos("Leões", 10)
g1.registrar_pontos("Tigres", 20)
g1.mostrar_pontuacoes()
print(g1.descricao())
g1.salvar_no_banco()

print("\n=== TESTE 2: Gincana temática ===")
g2 = GincanaTematica("Gincana Cultural", "2025-11-05", "Cultura Afro-Brasileira")
g2.adicionar_equipe("Mandinga")
g2.registrar_pontos("Mandinga", 30)
g2.mostrar_pontuacoes()
print(g2.descricao())
g2.salvar_no_banco()

print("\n=== CONSULTA AO BANCO ===")
Gincana.listar_gincanas()

print("\n=== EXCLUSÃO DE GINCANA (ID 1) ===")
Gincana.excluir_gincana(1)

print("\n=== CONSULTA FINAL ===")
Gincana.listar_gincanas()
# Out:
# === TESTE 1: Gincana comum ===
# ✅ Equipe 'Leões' adicionada.
# ✅ Equipe 'Tigres' adicionada.
# 📋 Pontuação da gincana 'Gincana Esportiva':
# - Leões: 10 ponto(s)
# - Tigres: 20 ponto(s)
# Gincana comum: Gincana Esportiva | Data: 2025-10-01
#
# === TESTE 2: Gincana temática ===
# ✅ Equipe 'Mandinga' adicionada.
# 📋 Pontuação da gincana 'Gincana Cultural':
# - Mandinga: 30 ponto(s)
# Gincana Temática: Gincana Cultural | Data: 2025-11-05 | Tema: Cultura Afro-Brasileira
#
# === CONSULTA AO BANCO ===
#
# 📚 Gincanas cadastradas:
# ID: 2 | Nome: Gincana Cultural | Data: 2025-09-20 | Tipo: Temática: Cultura Nordestina
# ID: 3 | Nome: Gincana Esportiva | Data: 2025-10-01 | Tipo: Comum
# ID: 4 | Nome: Gincana Cultural | Data: 2025-11-05 | Tipo: Temática: Cultura Afro-Brasileira
#
# === EXCLUSÃO DE GINCANA (ID 1) ===
# 🗑️ Gincana com ID 1 foi excluída.
#
# === CONSULTA FINAL ===
#
# 📚 Gincanas cadastradas:
# ...
